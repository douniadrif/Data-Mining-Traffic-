# %%
import pandas as pd

# %%
accidents = pd.read_csv('/Users/macosx/Downloads/Accident_Information.csv')
# Out:
# /Users/macosx/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
accidents.head(3)
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00001              A           3218.0            NaN
# 1  200501BS00002              B            450.0              C
# 2  200501BS00003              C              0.0            NaN
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0           Serious                None  2005-01-04
# 1              0.0            Slight                None  2005-01-05
# 2              0.0            Slight                None  2005-01-06
#
#   Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 0     Tuesday                                          1.0  ...
# 1   Wednesday                                          1.0  ...
# 2    Thursday                                          1.0  ...
#
#           Police_Force Road_Surface_Conditions           Road_Type  \
# 0  Metropolitan Police             Wet or damp  Single carriageway
# 1  Metropolitan Police                     Dry    Dual carriageway
# 2  Metropolitan Police                     Dry  Single carriageway
#
#   Special_Conditions_at_Site Speed_limit   Time  Urban_or_Rural_Area  \
# 0                       None        30.0  17:42                Urban
# 1                       None        30.0  17:36                Urban
# 2                       None        30.0  00:15                Urban
#
#       Weather_Conditions  Year InScotland
# 0  Raining no high winds  2005         No
# 1     Fine no high winds  2005         No
# 2     Fine no high winds  2005         No
#
# [3 rows x 34 columns]

# %%
#from pandas_profiling import ProfileReport
#prof=ProfileReport(accidents)
#prof.to_file(output_file ='report_accidents.html')

# %%
accidents.shape
# Out:
# (2047256, 34)

# %%
accidents.describe()
# Out:
#        1st_Road_Number  2nd_Road_Number  \
# count     2.047254e+06     2.029663e+06
# mean      9.921051e+02     3.728153e+02
# std       1.809408e+03     1.287796e+03
# min       0.000000e+00     0.000000e+00
# 25%       0.000000e+00     0.000000e+00
# 50%       1.180000e+02     0.000000e+00
# 75%       7.020000e+02     0.000000e+00
# max       9.999000e+03     9.999000e+03
#
#        Did_Police_Officer_Attend_Scene_of_Accident      Latitude  \
# count                                 2.046978e+06  2.047082e+06
# mean                                  1.202319e+00  5.255978e+01
# std                                   4.081935e-01  1.445506e+00
# min                                   1.000000e+00  4.991294e+01
# 25%                                   1.000000e+00  5.148540e+01
# 50%                                   1.000000e+00  5.223758e+01
# 75%                                   1.000000e+00  5.345590e+01
# max                                   3.000000e+00  6.075754e+01
#
#        Location_Easting_OSGR  Location_Northing_OSGR     Longitude  \
# count           2.047092e+06            2.047092e+06  2.047081e+06
# mean            4.414462e+05            2.968855e+05 -1.410155e+00
# std             9.549620e+04            1.605273e+05  1.403532e+00
# min             6.495000e+04            1.029000e+04 -7.516225e+00
# 25%             3.780635e+05            1.777568e+05 -2.329610e+00
# 50%             4.430500e+05            2.611835e+05 -1.362233e+00
# 75%             5.242982e+05            3.956100e+05 -2.052600e-01
# max             6.555400e+05            1.208800e+06  1.762010e+00
#
#        Number_of_Casualties  Number_of_Vehicles  \
# count          2.047256e+06        2.047256e+06
# mean           1.345843e+00        1.833525e+00
# std            8.179627e-01        7.150543e-01
# min            1.000000e+00        1.000000e+00
# 25%            1.000000e+00        1.000000e+00
# 50%            1.000000e+00        2.000000e+00
# 75%            1.000000e+00        2.000000e+00
# max            9.300000e+01        6.700000e+01
#
#        Pedestrian_Crossing-Human_Control  \
# count                       2.044336e+06
# mean                        1.041707e-02
# std                         1.351126e-01
# min                         0.000000e+00
# 25%                         0.000000e+00
# 50%                         0.000000e+00
# 75%                         0.000000e+00
# max                         2.000000e+00
#
#        Pedestrian_Crossing-Physical_Facilities   Speed_limit          Year
# count                             2.043696e+06  2.047219e+06  2.047256e+06
# mean                              7.518021e-01  3.884360e+01  2.010524e+03
# std                               1.835289e+00  1.414791e+01  3.765624e+00
# min                               0.000000e+00  0.000000e+00  2.005000e+03
# 25%                               0.000000e+00  3.000000e+01  2.007000e+03
# 50%                               0.000000e+00  3.000000e+01  2.010000e+03
# 75%                               0.000000e+00  5.000000e+01  2.014000e+03
# max                               8.000000e+00  7.000000e+01  2.017000e+03

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2047256 entries, 0 to 2047255
# Data columns (total 34 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   1st_Road_Class                               object
#  2   1st_Road_Number                              float64
#  3   2nd_Road_Class                               object
#  4   2nd_Road_Number                              float64
#  5   Accident_Severity                            object
#  6   Carriageway_Hazards                          object
#  7   Date                                         object
#  8   Day_of_Week                                  object
#  9   Did_Police_Officer_Attend_Scene_of_Accident  float64
#  10  Junction_Control                             object
#  11  Junction_Detail                              object
#  12  Latitude                                     float64
#  13  Light_Conditions                             object
#  14  Local_Authority_(District)                   object
#  15  Local_Authority_(Highway)                    object
#  16  Location_Easting_OSGR                        float64
#  17  Location_Northing_OSGR                       float64
#  18  Longitude                                    float64
#  19  LSOA_of_Accident_Location                    object
#  20  Number_of_Casualties                         int64
#  21  Number_of_Vehicles                           int64
#  22  Pedestrian_Crossing-Human_Control            float64
#  23  Pedestrian_Crossing-Physical_Facilities      float64
#  24  Police_Force                                 object
#  25  Road_Surface_Conditions                      object
#  26  Road_Type                                    object
#  27  Special_Conditions_at_Site                   object
#  28  Speed_limit                                  float64
#  29  Time                                         object
#  30  Urban_or_Rural_Area                          object
#  31  Weather_Conditions                           object
#  32  Year                                         int64
#  33  InScotland                                   object
# dtypes: float64(10), int64(3), object(21)
# memory usage: 531.1+ MB

# %%
accidents.isna().sum()
# Out:
# Accident_Index                                      0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     2
# 2nd_Road_Class                                 844272
# 2nd_Road_Number                                 17593
# Accident_Severity                                   0
# Carriageway_Hazards                                 0
# Date                                                0
# Day_of_Week                                         0
# Did_Police_Officer_Attend_Scene_of_Accident       278
# Junction_Control                                    0
# Junction_Detail                                     0
# Latitude                                          174
# Light_Conditions                                    0
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# Location_Easting_OSGR                             164
# Location_Northing_OSGR                            164
# Longitude                                         175
# LSOA_of_Accident_Location                      144953
# Number_of_Casualties                                0
# Number_of_Vehicles                                  0
# Pedestrian_Crossing-Human_Control                2920
# Pedestrian_Crossing-Physical_Facilities          3560
# Police_Force                                        0
# Road_Surface_Conditions                             0
# Road_Type                                           0
# Special_Conditions_at_Site                          0
# Speed_limit                                        37
# Time                                              156
# Urban_or_Rural_Area                                 0
# Weather_Conditions                                  0
# Year                                                0
# InScotland                                         53
# dtype: int64

# %%
accidents = accidents.dropna()

# %%
accidents.head(3)
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 1  200501BS00002              B            450.0              C
# 6  200501BS00007              C              0.0   Unclassified
# 8  200501BS00010              A           3212.0              B
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 1              0.0            Slight                None  2005-01-05
# 6              0.0            Slight                None  2005-01-13
# 8            304.0            Slight                None  2005-01-15
#
#   Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 1   Wednesday                                          1.0  ...
# 6    Thursday                                          1.0  ...
# 8    Saturday                                          1.0  ...
#
#           Police_Force Road_Surface_Conditions           Road_Type  \
# 1  Metropolitan Police                     Dry    Dual carriageway
# 6  Metropolitan Police                     Dry  Single carriageway
# 8  Metropolitan Police                     Dry  Single carriageway
#
#   Special_Conditions_at_Site Speed_limit   Time  Urban_or_Rural_Area  \
# 1                       None        30.0  17:36                Urban
# 6                       None        30.0  20:40                Urban
# 8                       None        30.0  22:43                Urban
#
#    Weather_Conditions  Year InScotland
# 1  Fine no high winds  2005         No
# 6  Fine no high winds  2005         No
# 8  Fine no high winds  2005         No
#
# [3 rows x 34 columns]

# %%
print(accidents.shape)
# Out:
# (1129974, 34)

# %% [markdown]
# ## Add Column Hours

# %%
accidents['Time'] = pd.to_datetime(accidents['Time'])

# %%
accidents['Hour'] =accidents['Time'].apply(lambda x: x.hour)

# %% [markdown]
# ## Data Visualisation

# %%
import matplotlib.pyplot as plt
ag = accidents.Accident_Severity.value_counts().sort_index()

plt.figure(figsize=(7,7))
ag.plot(kind='bar', subplots=True,figsize= (13,13))
plt.title('Accident Severity' , fontsize= 20)
plt.grid(False)

# %%
ag = accidents.Day_of_Week.value_counts().sort_index()
ag.plot(kind='bar',figsize= (7,7))
# Out:
# <AxesSubplot:>

# %%
ag = accidents.groupby('Accident_Severity').Road_Type.value_counts().sort_index()
ag.unstack()
# Out:
# Road_Type          Dual carriageway  One way street  Roundabout  \
# Accident_Severity
# Fatal                          1335             178         387
# Serious                       13609            3238       11749
# Slight                       104622           21745      115651
#
# Road_Type          Single carriageway  Slip road  Unknown
# Accident_Severity
# Fatal                            6469         87       26
# Serious                        109590       1144      488
# Slight                         721798      13012     4846

# %%
ag.unstack().plot(kind='bar', subplots=True, layout=(3,2),figsize= (10,10))
plt.show()

# %%
accidents['Hour'].value_counts().plot(kind='bar', subplots=True, layout=(3,2),figsize= (20,20))
plt.show()

# %%
ag = accidents.groupby('Accident_Severity').Urban_or_Rural_Area.value_counts().sort_index()
# ag.unstack()
ag.unstack().plot(kind='bar', subplots=True, layout=(3,3),figsize= (13,13))
plt.show()

# %%
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Daylight','light')
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Darkness - lights lit','dark')
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Darkness - lighting unknown','null')
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Darkness - lights unlit','dark')
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Darkness - no lighting','dark')
accidents["Light_Conditions"]=accidents["Light_Conditions"].replace('Data missing or out of range','null')

# %%
ag = accidents.groupby('Accident_Severity').Light_Conditions.value_counts().sort_index()
# ag.unstack()
ag.unstack().plot(kind='bar', subplots=True, layout=(3,3),figsize= (13,13))
plt.show()

# %%
accidents['Weather_Conditions'].value_counts().plot(kind='bar', subplots=True, layout=(3,2),figsize= (20,20))
plt.show()

# %%
accidents['Road_Surface_Conditions'].value_counts().plot(kind='bar', subplots=True, layout=(3,2),figsize= (20,20))
plt.show()

# %%
accidents['Road_Type'].value_counts().plot(kind='bar', subplots=True, layout=(3,2),figsize= (20,20))
plt.show()

# %%
accidents['Speed_limit'].value_counts().plot(kind='bar', subplots=True, layout=(3,2),figsize= (20,20))
plt.show()

# %%
severity1 = accidents[accidents['Accident_Severity'] == 'Fatal']
severity2 = accidents[accidents['Accident_Severity'] == 'Serious']
severity3 = accidents[accidents['Accident_Severity'] == 'Slight']

# %%
print(min(severity1['Longitude']))
print(max(severity1['Longitude']))
print(min(severity1['Latitude']))
print(max(severity1['Latitude']))
# Out:
# -5.563816
# 1.7368919999999999
# 50.075484
# 55.782135

# %%
import numpy as np
import matplotlib.image as mpimg

california_img=mpimg.imread('/Users/macosx/Desktop/map.png')
ax = severity1.plot(kind="scatter", x="Longitude", y="Latitude", figsize=(10,7),label='Fatal',
            c='Speed_limit',
                      
                      cmap=plt.get_cmap("jet"),
                       colorbar=False, alpha=0.4,
                      )
plt.imshow(california_img, extent=[-7.378267, 1.755184, 50.004371, 60.391536], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

#prices = housing["median_house_value"]
#tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar()
#cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median Speed Value', fontsize=16)

plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# ##  LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

accidents['Year']= LabelEncoder().fit_transform(accidents['Year'].astype(str))

accidents['Weather_Conditions']= LabelEncoder().fit_transform(accidents['Weather_Conditions'].astype(str))
accidents['Road_Surface_Conditions']= LabelEncoder().fit_transform(accidents['Road_Surface_Conditions'].astype(str))
accidents['Road_Type']= LabelEncoder().fit_transform(accidents['Road_Type'].astype(str))
accidents['Hour']= LabelEncoder().fit_transform(accidents['Hour'].astype(str))
accidents['Day_of_Week']= LabelEncoder().fit_transform(accidents['Day_of_Week'].astype(str))
accidents['Junction_Control']= LabelEncoder().fit_transform(accidents['Junction_Control'].astype(str))
accidents['Light_Conditions']= LabelEncoder().fit_transform(accidents['Light_Conditions'].astype(str))
accidents['Junction_Detail']= LabelEncoder().fit_transform(accidents['Junction_Detail'].astype(str))
accidents['Urban_or_Rural_Area']= LabelEncoder().fit_transform(accidents['Urban_or_Rural_Area'].astype(str))

# %%
accidents.shape
# Out:
# (1129974, 35)

# %%
accidents.head(3)
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 1  200501BS00002              B            450.0              C
# 6  200501BS00007              C              0.0   Unclassified
# 8  200501BS00010              A           3212.0              B
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 1              0.0            Slight                None  2005-01-05
# 6              0.0            Slight                None  2005-01-13
# 8            304.0            Slight                None  2005-01-15
#
#    Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 1            6                                          1.0  ...
# 6            4                                          1.0  ...
# 8            2                                          1.0  ...
#
#    Road_Surface_Conditions  Road_Type  Special_Conditions_at_Site  \
# 1                        1          0                        None
# 6                        1          3                        None
# 8                        1          3                        None
#
#    Speed_limit                Time Urban_or_Rural_Area  Weather_Conditions  \
# 1         30.0 2021-01-04 17:36:00                   1                   2
# 6         30.0 2021-01-04 20:40:00                   1                   2
# 8         30.0 2021-01-04 22:43:00                   1                   2
#
#    Year  InScotland Hour
# 1     0          No    9
# 6     0          No   13
# 8     0          No   15
#
# [3 rows x 35 columns]

# %% [markdown]
# ## Get_dummies

# %%
accidents=pd.get_dummies(accidents, columns=['Accident_Severity'])

# %%
accidents.head(3)
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 1  200501BS00002              B            450.0              C
# 6  200501BS00007              C              0.0   Unclassified
# 8  200501BS00010              A           3212.0              B
#
#    2nd_Road_Number Carriageway_Hazards        Date  Day_of_Week  \
# 1              0.0                None  2005-01-05            6
# 6              0.0                None  2005-01-13            4
# 8            304.0                None  2005-01-15            2
#
#    Did_Police_Officer_Attend_Scene_of_Accident  Junction_Control  ...  \
# 1                                          1.0                 1  ...
# 6                                          1.0                 3  ...
# 8                                          1.0                 1  ...
#
#    Speed_limit                Time  Urban_or_Rural_Area Weather_Conditions  \
# 1         30.0 2021-01-04 17:36:00                    1                  2
# 6         30.0 2021-01-04 20:40:00                    1                  2
# 8         30.0 2021-01-04 22:43:00                    1                  2
#
#   Year  InScotland  Hour  Accident_Severity_Fatal Accident_Severity_Serious  \
# 1    0          No     9                        0                         0
# 6    0          No    13                        0                         0
# 8    0          No    15                        0                         0
#
#    Accident_Severity_Slight
# 1                         1
# 6                         1
# 8                         1
#
# [3 rows x 37 columns]

# %%
accidents.Urban_or_Rural_Area.value_counts()
# Out:
# 1    858025
# 0    271949
# Name: Urban_or_Rural_Area, dtype: int64

# %%
accidents1=accidents[['Accident_Severity_Fatal','Accident_Severity_Serious','Accident_Severity_Slight','1st_Road_Class', '1st_Road_Number',  'Date',
       'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Latitude',
       'Light_Conditions', 'Longitude', 'Number_of_Casualties',
       'Number_of_Vehicles', 'Road_Surface_Conditions', 'Road_Type',
       'Speed_limit', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions',
       'Year','Hour']]

# %%
accidents1=pd.get_dummies(accidents1, columns=['Urban_or_Rural_Area'])

# %%
correlations = accidents1.corr(method='pearson')
correlations
# Out:
#                            Accident_Severity_Fatal  Accident_Severity_Serious  \
# Accident_Severity_Fatal                   1.000000                  -0.032680
# Accident_Severity_Serious                -0.032680                   1.000000
# Accident_Severity_Slight                 -0.223751                  -0.966814
# 1st_Road_Number                           0.000752                   0.001268
# Day_of_Week                              -0.004774                  -0.004479
# Junction_Control                          0.007524                   0.020924
# Junction_Detail                           0.005797                   0.014322
# Latitude                                  0.006539                   0.005508
# Light_Conditions                         -0.022004                  -0.033450
# Longitude                                -0.008600                  -0.002160
# Number_of_Casualties                      0.041251                   0.022506
# Number_of_Vehicles                       -0.020351                  -0.090236
# Road_Surface_Conditions                  -0.001696                  -0.011956
# Road_Type                                -0.007939                   0.017371
# Speed_limit                               0.049868                   0.027801
# Weather_Conditions                       -0.011490                  -0.024834
# Year                                     -0.008152                   0.034075
# Hour                                     -0.003441                  -0.001964
# Urban_or_Rural_Area_0                     0.038990                   0.032518
# Urban_or_Rural_Area_1                    -0.038990                  -0.032518
#
#                            Accident_Severity_Slight  1st_Road_Number  \
# Accident_Severity_Fatal                   -0.223751         0.000752
# Accident_Severity_Serious                 -0.966814         0.001268
# Accident_Severity_Slight                   1.000000        -0.001429
# 1st_Road_Number                           -0.001429         1.000000
# Day_of_Week                                0.005589        -0.001016
# Junction_Control                          -0.022327        -0.024833
# Junction_Detail                           -0.015448        -0.014607
# Latitude                                  -0.007043         0.096331
# Light_Conditions                           0.038244        -0.003236
# Longitude                                  0.004304        -0.135789
# Number_of_Casualties                      -0.032492         0.019531
# Number_of_Vehicles                         0.093197         0.014865
# Road_Surface_Conditions                    0.012092         0.022783
# Road_Type                                 -0.014910         0.004043
# Speed_limit                               -0.039858        -0.030949
# Weather_Conditions                         0.027155         0.014494
# Year                                      -0.031145        -0.016016
# Hour                                       0.002795        -0.001424
# Urban_or_Rural_Area_0                     -0.041677        -0.004260
# Urban_or_Rural_Area_1                      0.041677         0.004260
#
#                            Day_of_Week  Junction_Control  Junction_Detail  \
# Accident_Severity_Fatal      -0.004774          0.007524         0.005797
# Accident_Severity_Serious    -0.004479          0.020924         0.014322
# Accident_Severity_Slight      0.005589         -0.022327        -0.015448
# 1st_Road_Number              -0.001016         -0.024833        -0.014607
# Day_of_Week                   1.000000          0.005652         0.004587
# Junction_Control              0.005652          1.000000         0.328713
# Junction_Detail               0.004587          0.328713         1.000000
# Latitude                     -0.005991          0.006694        -0.022533
# Light_Conditions              0.024791          0.051547         0.032212
# Longitude                     0.002881         -0.027404         0.022336
# Number_of_Casualties         -0.018031         -0.016697        -0.043305
# Number_of_Vehicles            0.008515          0.012700        -0.028264
# Road_Surface_Conditions      -0.000693          0.020382        -0.004999
# Road_Type                     0.000961          0.176559         0.074307
# Speed_limit                  -0.000767          0.090473         0.042672
# Weather_Conditions           -0.005597          0.003287        -0.007858
# Year                          0.002982         -0.012638         0.004497
# Hour                          0.038921          0.005575         0.003970
# Urban_or_Rural_Area_0         0.000153          0.149364         0.066420
# Urban_or_Rural_Area_1        -0.000153         -0.149364        -0.066420
#
#                            Latitude  Light_Conditions  Longitude  \
# Accident_Severity_Fatal    0.006539         -0.022004  -0.008600
# Accident_Severity_Serious  0.005508         -0.033450  -0.002160
# Accident_Severity_Slight  -0.007043          0.038244   0.004304
# 1st_Road_Number            0.096331         -0.003236  -0.135789
# Day_of_Week               -0.005991          0.024791   0.002881
# Junction_Control           0.006694          0.051547  -0.027404
# Junction_Detail           -0.022533          0.032212   0.022336
# Latitude                   1.000000          0.010378  -0.302511
# Light_Conditions           0.010378          1.000000  -0.023069
# Longitude                 -0.302511         -0.023069   1.000000
# Number_of_Casualties       0.073615         -0.029274  -0.063892
# Number_of_Vehicles         0.011270          0.060415  -0.028145
# Road_Surface_Conditions    0.055396         -0.193241  -0.060405
# Road_Type                 -0.014730          0.026672   0.011686
# Speed_limit                0.023397          0.026364  -0.051064
# Weather_Conditions         0.023292         -0.080142  -0.039101
# Year                      -0.056016          0.006758   0.058668
# Hour                      -0.031895         -0.089627   0.029441
# Urban_or_Rural_Area_0      0.027819          0.051310  -0.089748
# Urban_or_Rural_Area_1     -0.027819         -0.051310   0.089748
#
#                            Number_of_Casualties  Number_of_Vehicles  \
# Accident_Severity_Fatal                0.041251           -0.020351
# Accident_Severity_Serious              0.022506           -0.090236
# Accident_Severity_Slight              -0.032492            0.093197
# 1st_Road_Number                        0.019531            0.014865
# Day_of_Week                           -0.018031            0.008515
# Junction_Control                      -0.016697            0.012700
# Junction_Detail                       -0.043305           -0.028264
# Latitude                               0.073615            0.011270
# Light_Conditions                      -0.029274            0.060415
# Longitude                             -0.063892           -0.028145
# Number_of_Casualties                   1.000000            0.207090
# Number_of_Vehicles                     0.207090            1.000000
# Road_Surface_Conditions                0.032105           -0.001263
# Road_Type                             -0.024997           -0.031879
# Speed_limit                            0.117068            0.110086
# Weather_Conditions                     0.002817           -0.009724
# Year                                  -0.020940           -0.010938
# Hour                                  -0.038478            0.001886
# Urban_or_Rural_Area_0                  0.096663            0.088336
# Urban_or_Rural_Area_1                 -0.096663           -0.088336
#
#                            Road_Surface_Conditions  Road_Type  Speed_limit  \
# Accident_Severity_Fatal                  -0.001696  -0.007939     0.049868
# Accident_Severity_Serious                -0.011956   0.017371     0.027801
# Accident_Severity_Slight                  0.012092  -0.014910    -0.039858
# 1st_Road_Number                           0.022783   0.004043    -0.030949
# Day_of_Week                              -0.000693   0.000961    -0.000767
# Junction_Control                          0.020382   0.176559     0.090473
# Junction_Detail                          -0.004999   0.074307     0.042672
# Latitude                                  0.055396  -0.014730     0.023397
# Light_Conditions                         -0.193241   0.026672     0.026364
# Longitude                                -0.060405   0.011686    -0.051064
# Number_of_Casualties                      0.032105  -0.024997     0.117068
# Number_of_Vehicles                       -0.001263  -0.031879     0.110086
# Road_Surface_Conditions                   1.000000  -0.005695     0.047680
# Road_Type                                -0.005695   1.000000    -0.186486
# Speed_limit                               0.047680  -0.186486     1.000000
# Weather_Conditions                        0.505508  -0.000083    -0.003215
# Year                                     -0.027300   0.002056    -0.049014
# Hour                                      0.074501  -0.002476     0.002343
# Urban_or_Rural_Area_0                     0.045922  -0.019848     0.633471
# Urban_or_Rural_Area_1                    -0.045922   0.019848    -0.633471
#
#                            Weather_Conditions      Year      Hour  \
# Accident_Severity_Fatal             -0.011490 -0.008152 -0.003441
# Accident_Severity_Serious           -0.024834  0.034075 -0.001964
# Accident_Severity_Slight             0.027155 -0.031145  0.002795
# 1st_Road_Number                      0.014494 -0.016016 -0.001424
# Day_of_Week                         -0.005597  0.002982  0.038921
# Junction_Control                     0.003287 -0.012638  0.005575
# Junction_Detail                     -0.007858  0.004497  0.003970
# Latitude                             0.023292 -0.056016 -0.031895
# Light_Conditions                    -0.080142  0.006758 -0.089627
# Longitude                           -0.039101  0.058668  0.029441
# Number_of_Casualties                 0.002817 -0.020940 -0.038478
# Number_of_Vehicles                  -0.009724 -0.010938  0.001886
# Road_Surface_Conditions              0.505508 -0.027300  0.074501
# Road_Type                           -0.000083  0.002056 -0.002476
# Speed_limit                         -0.003215 -0.049014  0.002343
# Weather_Conditions                   1.000000 -0.013085  0.026988
# Year                                -0.013085  1.000000  0.010467
# Hour                                 0.026988  0.010467  1.000000
# Urban_or_Rural_Area_0               -0.003720 -0.007469 -0.001189
# Urban_or_Rural_Area_1                0.003720  0.007469  0.001189
#
#                            Urban_or_Rural_Area_0  Urban_or_Rural_Area_1
# Accident_Severity_Fatal                 0.038990              -0.038990
# Accident_Severity_Serious               0.032518              -0.032518
# Accident_Severity_Slight               -0.041677               0.041677
# 1st_Road_Number                        -0.004260               0.004260
# Day_of_Week                             0.000153              -0.000153
# Junction_Control                        0.149364              -0.149364
# Junction_Detail                         0.066420              -0.066420
# Latitude                                0.027819              -0.027819
# Light_Conditions                        0.051310              -0.051310
# Longitude                              -0.089748               0.089748
# Number_of_Casualties                    0.096663              -0.096663
# Number_of_Vehicles                      0.088336              -0.088336
# Road_Surface_Conditions                 0.045922              -0.045922
# Road_Type                              -0.019848               0.019848
# Speed_limit                             0.633471              -0.633471
# Weather_Conditions                     -0.003720               0.003720
# Year                                   -0.007469               0.007469
# Hour                                   -0.001189               0.001189
# Urban_or_Rural_Area_0                   1.000000              -1.000000
# Urban_or_Rural_Area_1                  -1.000000               1.000000

# %%
from matplotlib import pyplot
accidents1.hist()
pyplot.show()

# %% [markdown]
# ## MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
accidents = MinMaxScaler(feature_range=(0,1))
accidents = accidents.fit_transform(accidents1[['Speed_limit']])

# %%
accidents1.head(3)
# Out:
#    Accident_Severity_Fatal  Accident_Severity_Serious  \
# 1                        0                          0
# 6                        0                          0
# 8                        0                          0
#
#    Accident_Severity_Slight 1st_Road_Class  1st_Road_Number        Date  \
# 1                         1              B            450.0  2005-01-05
# 6                         1              C              0.0  2005-01-13
# 8                         1              A           3212.0  2005-01-15
#
#    Day_of_Week  Junction_Control  Junction_Detail   Latitude  ...  \
# 1            6                 1                0  51.520075  ...
# 6            4                 3                9  51.512695  ...
# 8            2                 1                0  51.483420  ...
#
#    Number_of_Vehicles  Road_Surface_Conditions  Road_Type  Speed_limit  \
# 1                   1                        1          0         30.0
# 6                   2                        1          3         30.0
# 8                   2                        1          3         30.0
#
#                  Time  Weather_Conditions  Year Hour  Urban_or_Rural_Area_0  \
# 1 2021-01-04 17:36:00                   2     0    9                      0
# 6 2021-01-04 20:40:00                   2     0   13                      0
# 8 2021-01-04 22:43:00                   2     0   15                      0
#
#    Urban_or_Rural_Area_1
# 1                      1
# 6                      1
# 8                      1
#
# [3 rows x 23 columns]

# %%
accidents1.drop(columns=['1st_Road_Class'])
# Out:
#          Accident_Severity_Fatal  Accident_Severity_Serious  \
# 1                              0                          0
# 6                              0                          0
# 8                              0                          0
# 9                              0                          0
# 10                             0                          0
# ...                          ...                        ...
# 2040128                        0                          0
# 2040130                        0                          0
# 2040138                        0                          1
# 2040140                        0                          0
# 2040142                        0                          0
#
#          Accident_Severity_Slight  1st_Road_Number        Date  Day_of_Week  \
# 1                               1            450.0  2005-01-05            6
# 6                               1              0.0  2005-01-13            4
# 8                               1           3212.0  2005-01-15            2
# 9                               1            450.0  2005-01-15            2
# 10                              1              4.0  2005-01-16            3
# ...                           ...              ...         ...          ...
# 2040128                         1            483.0  2017-03-08            6
# 2040130                         1              0.0  2017-03-15            6
# 2040138                         0           4358.0  2017-03-20            1
# 2040140                         1              0.0  2017-02-03            0
# 2040142                         1            470.0  2017-02-19            3
#
#          Junction_Control  Junction_Detail   Latitude  Light_Conditions  ...  \
# 1                       1                0  51.520075                 0  ...
# 6                       3                9  51.512695                 0  ...
# 8                       1                0  51.483420                 0  ...
# 9                       3                9  51.512443                 1  ...
# 10                      1                0  51.494902                 0  ...
# ...                   ...              ...        ...               ...  ...
# 2040128                 3                9  52.746141                 1  ...
# 2040130                 3                9  52.516585                 1  ...
# 2040138                 3                6  52.225826                 1  ...
# 2040140                 3                9  51.861039                 1  ...
# 2040142                 3                9  52.170798                 1  ...
#
#          Number_of_Vehicles  Road_Surface_Conditions  Road_Type  Speed_limit  \
# 1                         1                        1          0         30.0
# 6                         2                        1          3         30.0
# 8                         2                        1          3         30.0
# 9                         2                        1          3         30.0
# 10                        1                        1          3         30.0
# ...                     ...                      ...        ...          ...
# 2040128                   3                        1          3         60.0
# 2040130                   1                        1          3         30.0
# 2040138                   2                        5          3         60.0
# 2040140                   3                        4          3         30.0
# 2040142                   1                        5          3         60.0
#
#                        Time  Weather_Conditions Year  Hour  \
# 1       2021-01-04 17:36:00                   2    0     9
# 6       2021-01-04 20:40:00                   2    0    13
# 8       2021-01-04 22:43:00                   2    0    15
# 9       2021-01-04 16:00:00                   2    0     8
# 10      2021-01-04 00:42:00                   2    0     0
# ...                     ...                 ...  ...   ...
# 2040128 2021-01-04 15:20:00                   2   12     7
# 2040130 2021-01-04 13:45:00                   2   12     5
# 2040138 2021-01-04 11:45:00                   6   12     3
# 2040140 2021-01-04 06:36:00                   2   12    20
# 2040142 2021-01-04 13:34:00                   2   12     5
#
#          Urban_or_Rural_Area_0  Urban_or_Rural_Area_1
# 1                            0                      1
# 6                            0                      1
# 8                            0                      1
# 9                            0                      1
# 10                           0                      1
# ...                        ...                    ...
# 2040128                      1                      0
# 2040130                      0                      1
# 2040138                      1                      0
# 2040140                      1                      0
# 2040142                      1                      0
#
# [1129974 rows x 22 columns]

# %%
accidents1.shape
# Out:
# (1129974, 23)

# %%
accidents1.columns
# Out:
# Index(['Accident_Severity_Fatal', 'Accident_Severity_Serious',
#        'Accident_Severity_Slight', '1st_Road_Class', '1st_Road_Number', 'Date',
#        'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Latitude',
#        'Light_Conditions', 'Longitude', 'Number_of_Casualties',
#        'Number_of_Vehicles', 'Road_Surface_Conditions', 'Road_Type',
#        'Speed_limit', 'Time', 'Weather_Conditions', 'Year', 'Hour',
#        'Urban_or_Rural_Area_0', 'Urban_or_Rural_Area_1'],
#       dtype='object')

# %%
df=accidents1[['Accident_Severity_Fatal', 'Accident_Severity_Serious',
       'Accident_Severity_Slight', '1st_Road_Number',
       'Day_of_Week', 'Junction_Control', 'Junction_Detail',
       'Light_Conditions',  'Number_of_Casualties',
       'Number_of_Vehicles', 'Road_Surface_Conditions', 'Road_Type',
       'Speed_limit', 'Weather_Conditions', 'Year', 'Hour']]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from numpy import set_printoptions
array = accidents1.values

X = df
Y = accidents1['Accident_Severity_Fatal']

test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X,Y)

# %%
set_printoptions(precision=2)
print(fit.scores_)
featured_data = fit.transform(X)
print ("\nFeatured data:\n", featured_data[0:4])
# Out:
# [1.12e+06 1.06e+03 7.42e+03 2.03e+03 3.71e+01 1.56e+01 6.33e+01 1.46e+02
#  8.42e+02 8.96e+01 4.84e+00 2.74e+01 1.00e+04 1.50e+02 1.89e+02 5.40e+01]
#
# Featured data:
#  [[0.00e+00 1.00e+00 4.50e+02 3.00e+01]
#  [0.00e+00 1.00e+00 0.00e+00 3.00e+01]
#  [0.00e+00 1.00e+00 3.21e+03 3.00e+01]
#  [0.00e+00 1.00e+00 4.50e+02 3.00e+01]]

# %% [markdown]
# ## Correlation

# %%
import numpy as np
import seaborn as sns
target = 'Accident_Severity_Serious'
#plot heatmap
def plot_corr_matrix(df, nr_c, targ) :
    
    corr = df.corr()
    corr_abs = corr.abs()
    cols = corr_abs.nlargest(nr_c, targ)[targ].index
    cm = np.corrcoef(df[cols].values.T)

    plt.figure(figsize=(12, 12))
    sns.set(font_scale=1.25)
    sns.heatmap(cm, linewidths=1.5, annot=True, square=True, 
                fmt='.2f', annot_kws={'size': 10}, 
                yticklabels=cols.values, xticklabels=cols.values
               )
    #plt.savefig('/Users/pprusty05/google_drive/Data_Mining/Project/plots/correlation.pdf')
    plt.show()
    
    

#set the threshold for feature selection
corr_theshold=.01

#find the correlation values
corr = accidents1.corr()
corr_abs = corr.abs()

num_cols = len(accidents1)
#sort the correlation values in descending order
sort_corr = corr_abs.nlargest(num_cols, target)[target]
#print(sort_corr)

#filter the features with above correlation values
cols_abv_corr_limit = list(sort_corr[sort_corr.values > corr_theshold].index)
cols_bel_corr_limit = list(sort_corr[sort_corr.values <= corr_theshold].index)
selected_feats=cols_abv_corr_limit
nr_feats = len(cols_abv_corr_limit)

#plot the heatmap with selected features
plot_corr_matrix(accidents1, nr_feats, target)

#drop the features from df_train with correaltion value below threshold
#for df in [df_dummies]:
    #df.drop(cols_bel_corr_limit, inplace=True, axis=1)

print("Final list of selected features:")
print(selected_feats)
# Out:
# Final list of selected features:
# ['Accident_Severity_Serious', 'Accident_Severity_Slight', 'Number_of_Vehicles', 'Year', 'Light_Conditions', 'Accident_Severity_Fatal', 'Urban_or_Rural_Area_0', 'Urban_or_Rural_Area_1', 'Speed_limit', 'Weather_Conditions', 'Number_of_Casualties', 'Junction_Control', 'Road_Type', 'Junction_Detail', 'Road_Surface_Conditions']

# %% [markdown]
# # Machine learning Models

# %% [markdown]
# ### Train-Test

# %%
#train_under = pd.concat([df_slight_under, df_serious_under, df_fatal], axis=0)

df1 = accidents1[['Road_Surface_Conditions','Road_Type','Hour','Day_of_Week','Light_Conditions','Junction_Detail','Weather_Conditions','Number_of_Vehicles']]
#df1 = accidents1[['Weather_Conditions']]

# %%
X = df1
y = accidents1['Accident_Severity_Fatal']

# %%
import sklearn
from sklearn import datasets
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %% [markdown]
# ## Logistic Regression

# %%
digreg = linear_model.LogisticRegression()

# %%
digreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = digreg.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result0 = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result0)
result01 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result01)
result02 = accuracy_score(y_test,y_pred)
print("Accuracy:",result02)
# Out:
# Confusion Matrix:
# [[448551      0]
#  [  3439      0]]
# /Users/macosx/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    448551
#            1       0.00      0.00      0.00      3439
#
#     accuracy                           0.99    451990
#    macro avg       0.50      0.50      0.50    451990
# weighted avg       0.98      0.99      0.99    451990
#
# Accuracy: 0.9923914245890396

# %%
print("Accuracy of Logistic Regression model is:",
metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy of Logistic Regression model is: 99.23914245890396

# %%
print("Test Error = %g " % (1.0 - metrics.accuracy_score(y_test, y_pred)))
# Out:
# Test Error = 0.00760858

# %%
from sklearn import linear_model
import sklearn.metrics as sm

# %%
plt.figure(figsize=(9,9))
sns.heatmap(result0, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Greens');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(result02)
plt.title(all_sample_title, size = 15);

# %%
print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, y_pred), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, y_pred), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2))
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 1.94
# Mean squared error(MSE) = 0.01
# Median absolute error = 0.0
# Explain variance score = 0.0
# R2 score = -0.01

# %% [markdown]
# ## Décision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
y_pred1 = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result00 = confusion_matrix(y_test, y_pred1)
print("Confusion Matrix:")
print(result00)
result001 = classification_report(y_test, y_pred1)
print("Classification Report:",)
print (result001)
result002 = accuracy_score(y_test,y_pred1)
print("Accuracy:",result002)
# Out:
# Confusion Matrix:
# [[448132    419]
#  [  3433      6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    448551
#            1       0.01      0.00      0.00      3439
#
#     accuracy                           0.99    451990
#    macro avg       0.50      0.50      0.50    451990
# weighted avg       0.98      0.99      0.99    451990
#
# Accuracy: 0.9914776875594593

# %%
plt.figure(figsize=(9,9))
sns.heatmap(result00, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Greens');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(result002)
plt.title(all_sample_title, size = 15);

# %%
print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, y_pred1), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, y_pred1), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred1), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred1), 2))
print("R2 score =", round(sm.r2_score(y_test, y_pred1), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 1.94
# Mean squared error(MSE) = 0.01
# Median absolute error = 0.0
# Explain variance score = -7975.36
# R2 score = -0.13

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=50)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred2 = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result000 = confusion_matrix(y_test, y_pred2)
print("Confusion Matrix:")
print(result000)
result0001 = classification_report(y_test, y_pred2)
print("Classification Report:",)
print (result0001)
result0002 = accuracy_score(y_test,y_pred2)
print("Accuracy:",result0002)
# Out:
# Confusion Matrix:
# [[448371    180]
#  [  3434      5]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    448551
#            1       0.03      0.00      0.00      3439
#
#     accuracy                           0.99    451990
#    macro avg       0.51      0.50      0.50    451990
# weighted avg       0.99      0.99      0.99    451990
#
# Accuracy: 0.9920042478815903

# %%
plt.figure(figsize=(9,9))
sns.heatmap(result000, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Greens');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(result0002)
plt.title(all_sample_title, size = 15);

# %%
print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, y_pred2), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, y_pred2), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred2), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred2), 2))
print("R2 score =", round(sm.r2_score(y_test, y_pred2), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 1.94
# Mean squared error(MSE) = 0.01
# Median absolute error = 0.0
# Explain variance score = -3427.98
# R2 score = -0.06

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
model6 = gnb.fit(X_train, y_train)

# %%
preds = gnb.predict(X_test)
print(preds)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,preds))
# Out:
# 0.9895816279121219

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result0000 = confusion_matrix(y_test, preds)
print("Confusion Matrix:")
print(result0000)
result00001 = classification_report(y_test, preds)
print("Classification Report:",)
print (result00001)
result00002 = accuracy_score(y_test,preds)
print("Accuracy:",result00002)
# Out:
# Confusion Matrix:
# [[447249   1302]
#  [  3407     32]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    448551
#            1       0.02      0.01      0.01      3439
#
#     accuracy                           0.99    451990
#    macro avg       0.51      0.50      0.50    451990
# weighted avg       0.99      0.99      0.99    451990
#
# Accuracy: 0.9895816279121219

# %%
plt.figure(figsize=(9,9))
sns.heatmap(result0000, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Greens');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(result00002)
plt.title(all_sample_title, size = 15);

# %%
print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, preds), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, preds), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, preds), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, preds), 2))
print("R2 score =", round(sm.r2_score(y_test, preds), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 1.93
# Mean squared error(MSE) = 0.01
# Median absolute error = 0.0
# Explain variance score = -24734.17
# R2 score = -0.38

# %%
estimators = []

estimators.append(('LogisticRegression', result02))

estimators.append(('Decisiontree', result002))

estimators.append(('Random forest', result0002))

#estimators.append(('Linear regression ', result0002))
#estimators.append(('SVM', result00002))
estimators.append(('Naive Bayes ', result00002))



print("comparator of accurancy from differents models : " , estimators)
